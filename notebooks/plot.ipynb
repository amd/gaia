# %%
feedback_data = """
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: Not for now; Additional Topics: Real lige samples
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: no; Additional Topics: no
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: N\A; Additional Topics: None!
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Need to try; Additional Topics: Need to try
----------
2023-06-30 | Prospect Notes Update:
Attended MSFT Build May 2023.
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: N/A; Additional Topics: N/A
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: N/A; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Advanced; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Na; Additional Topics: Demo of use case
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: NA; Additional Topics: NA
----------
2023-06-30 | Prospect Notes Update:
Attended MSFT Build May 2023.
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: The user interface is great and I loved the demo. Would love to use more for a longer time and provide more feedback; Additional Topics: Would definitely need a longer session yo fully try out, but I understand it’s not possible right now due to high number of people waiting
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: None; Additional Topics: NLP
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Advanced; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Faster computing; Additional Topics: More practical demo
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Faster processing; Additional Topics: Na
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: N/A; Additional Topics: N/A
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Faster ai computing; Additional Topics: How to utilize AMD to optimize AI queries
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: NA; Additional Topics: NA
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Not interested / Not Relevant; Feature Requests or Changes: Not at this time; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: NA; Additional Topics: NA
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Nope; Additional Topics: Nope
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Easy to use.; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: no; Additional Topics: Security
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Advanced; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Just to know what vector stores are available; Additional Topics: Information about configuration of relevance
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Yes; Additional Topics: Yes
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: N/A; Additional Topics: N/A
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Not yet; Additional Topics: Thank you for the demo
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: N/a; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: no; Additional Topics: no
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: Na; Additional Topics: Na
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: N/a; Additional Topics: N/a
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: More kernel dev; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: None; Additional Topics: None
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: N; Additional Topics: N
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: None; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Ask questions about statistics of the repository; Additional Topics: -
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Not currently; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: NA; Additional Topics: Na
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Not at the moment; Additional Topics: Not at the moment
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Linux desktop support; Additional Topics: Developer tooling
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: Not at the moment
----------
2021-11-24 | Prospect Notes Update:
Registered and/or attended Microsoft Ignite 2021 virtual event."
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Music creation; Additional Topics: Video generation
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; Intermediate; Advanced; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Not sure; Additional Topics: Not sure
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Na; Additional Topics: Na
----------
2023-06-30 | Prospect Notes Update:
Attended MSFT Build May 2023.
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: faster model training; Additional Topics: LLM training and finetuning
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: ; Deployment Method: ; Tools of Interest: ; Level of Experience: Advanced; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Ai; Additional Topics: Nope
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Deployment Method: Cloud / Data Center; Tools of Interest: ROCm Software; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Agentic functionality; Additional Topics: Benchmarks
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Speech Recognition / Synthesis; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Computer Vision; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: N/a; Additional Topics: N/a
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Recommendation System; Deployment Method: Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Advanced; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Not interested / Not Relevant; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Deployment Method: Laptop, Tablet, or Smartphone; Tools of Interest: ZenDNN Library; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Not interested / Not Relevant; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Yes; Additional Topics: Yes
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Computer Vision; Speech Recognition / Synthesis; Data Analytics; Cybersecurity; Deployment Method: Cloud / Data Center; Edge Server; Workstation or Desktop; Tools of Interest: ROCm Software; Ryzen AI Software; ZenDNN Library; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Not sure yet; Additional Topics: Not sure yet
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Recommendation System; Data Analytics; Deployment Method: Cloud / Data Center; Workstation or Desktop; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Ai implementation; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Cybersecurity; Deployment Method: Edge Server; Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-21 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Recommendation System; Deployment Method: Cloud / Data Center; Workstation or Desktop; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Image / Video Generation; Computer Vision; Data Analytics; Cybersecurity; Deployment Method: Cloud / Data Center; Workstation or Desktop; Tools of Interest: Ryzen AI Software; Vitis AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Not interested / Not Relevant; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Data Analytics; Deployment Method: Cloud / Data Center; Workstation or Desktop; Tools of Interest: ROCm Software; Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: RAG with personal documents on device; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Data Analytics; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Computer Vision; Recommendation System; Cybersecurity; Deployment Method: Cloud / Data Center; Edge Server; Workstation or Desktop; Laptop, Tablet, or Smartphone; Embedded Systems; Tools of Interest: ROCm Software; Ryzen AI Software; Vitis AI Software; ZenDNN Library; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: -; Additional Topics: -
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Data Analytics; Cybersecurity; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: Not at the moment; Additional Topics: Not at the moment
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Nothing; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Speech Recognition / Synthesis; Recommendation System; Cybersecurity; Deployment Method: Cloud / Data Center; Edge Server; Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: ROCm Software; Ryzen AI Software; Level of Experience: Beginner; Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: None that I can think of yet; Additional Topics: Walking through a scenario where we can see a concept come together.
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Speech Recognition / Synthesis; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Recommendation System; Deployment Method: Cloud / Data Center; Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Na; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Image / Video Generation; Speech Recognition / Synthesis; Deployment Method: Cloud / Data Center; Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: ROCm Software; Ryzen AI Software; Vitis AI Software; ZenDNN Library; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Discussed with presenter; Additional Topics: N/a
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Na; Additional Topics: Na
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Deployment Method: Cloud / Data Center; Tools of Interest: ROCm Software; Ryzen AI Software; Level of Experience: Advanced; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: Azure Devops repo support; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Recommendation System; Data Analytics; Deployment Method: Cloud / Data Center; Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: no; Additional Topics: compare performance to computer without and NPU and one with an AMD chip
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Data Analytics; Deployment Method: Cloud / Data Center; Tools of Interest: ROCm Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Image / Video Generation; Deployment Method: Laptop, Tablet, or Smartphone; Tools of Interest: ROCm Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Computer Vision; Deployment Method: Workstation or Desktop; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: N/A; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Recommendation System; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: Would like to see a GitHub version of the demo softeare
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Speech Recognition / Synthesis; Reinforcement Learning; Data Analytics; Deployment Method: Cloud / Data Center; Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: ROCm Software; Ryzen AI Software; Vitis AI Software; ZenDNN Library; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Not interested / Not Relevant; Feature Requests or Changes: -; Additional Topics: -
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Image / Video Generation; Deployment Method: Laptop, Tablet, or Smartphone; Embedded Systems; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Easier deployment; Additional Topics: Industry specific use cases
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Computer Vision; Speech Recognition / Synthesis; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: Na; Additional Topics: Na
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Deployment Method: Cloud / Data Center; Edge Server; Workstation or Desktop; Tools of Interest: ROCm Software; Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Na; Additional Topics: Na
----------
2023-06-30 | Prospect Notes Update:
Attended MSFT Build May 2023.
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Data Analytics; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Slightly Interested; Feature Requests or Changes: N/A; Additional Topics: N/A
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Computer Vision; Speech Recognition / Synthesis; Recommendation System; Reinforcement Learning; Data Analytics; Cybersecurity; Deployment Method: Cloud / Data Center; Edge Server; Workstation or Desktop; Embedded Systems; Tools of Interest: ROCm Software; Ryzen AI Software; Vitis AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: A preamble of suggested use cases.; Additional Topics: Image generation from webcam, or live translation from video
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Image / Video Generation; Speech Recognition / Synthesis; Recommendation System; Data Analytics; Cybersecurity; Deployment Method: Cloud / Data Center; Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: ROCm Software; Ryzen AI Software; Vitis AI Software; ZenDNN Library; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: None; Additional Topics: None
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Data Analytics; Deployment Method: Cloud / Data Center; Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Advanced; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Recommendation System; Deployment Method: Cloud / Data Center; Edge Server; Laptop, Tablet, or Smartphone; Tools of Interest: ROCm Software; Ryzen AI Software; Level of Experience: Intermediate; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: ai; Additional Topics: nope!
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Not interested / Not Relevant; Feature Requests or Changes: Na; Additional Topics: Na
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Computer Vision; Speech Recognition / Synthesis; Recommendation System; Reinforcement Learning; Cybersecurity; Deployment Method: Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: ZenDNN Library; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Computer Vision; Speech Recognition / Synthesis; Deployment Method: Cloud / Data Center; Edge Server; Workstation or Desktop; Laptop, Tablet, or Smartphone; Embedded Systems; Tools of Interest: ROCm Software; Ryzen AI Software; ZenDNN Library; Level of Experience: Intermediate; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Computer Vision; Deployment Method: Cloud / Data Center; Workstation or Desktop; Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: I don't believe I am at the technical level for that yet; Additional Topics: None
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Computer Vision; Deployment Method: Edge Server; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: Local storage; Additional Topics: Difference between cloud and local performance
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Data Analytics; Deployment Method: Cloud / Data Center; Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Satisfied; How Interested in Implementing: Not interested / Not Relevant; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Speech Recognition / Synthesis; Deployment Method: Cloud / Data Center; Laptop, Tablet, or Smartphone; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: None; Additional Topics: None
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Large Language Model (LLM); Natural Language Processing (NLP); Image / Video Generation; Speech Recognition / Synthesis; Recommendation System; Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Very Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"2024-05-22 | Prospect Notes Update:
Microsoft Build AMD Developer Feedback Survey Sweepstakes - AI Applications: Natural Language Processing (NLP); Deployment Method: Cloud / Data Center; Tools of Interest: Ryzen AI Software; Level of Experience: Beginner; How Satisfied with Solution: Very satisfied; How Interested in Implementing: Interested; Feature Requests or Changes: No; Additional Topics: No
----------"
"""

# %%
import re
from pprint import pprint

def split_feedback_data(feedback_data):
    # Split the feedback data into a list of individual entries
    feedback_entries = feedback_data.split("----------")
    # Remove any leading/trailing whitespace from each entry
    feedback_entries = [entry.strip() for entry in feedback_entries if entry.strip()]

    feedback = []
    for entry in feedback_entries:
        feedback.append(entry.split(';'))

    # return feedback_entries
    return feedback

feedback_entries = split_feedback_data(feedback_data)
# feedback_entries_filtered = [item for item in feedback_entries if item not in ["None", "NaN", "Nope"]]
# pprint(feedback_entries)

# %%
import matplotlib.pyplot as plt

def plot_feedback_histogram(feedback_entries):
    # Extract the feedback values using regular expressions
    satisfaction_values = []
    interest_values = []
    satisfaction_counts = {}
    interest_counts = {}

    for entries in feedback_entries:
        for entry in entries:
            satisfaction_match = re.search(r'How Satisfied with Solution: (.+)', entry)
            interest_match = re.search(r'How Interested in Implementing: (.+)', entry)

            if satisfaction_match:
                entry = satisfaction_match.group(1)
                satisfaction_values.append(entry)
                if entry in satisfaction_counts:
                    satisfaction_counts[entry] += 1
                else:
                    satisfaction_counts[entry] = 1

            if interest_match:
                entry = interest_match.group(1)
                interest_values.append(entry)
                if entry in interest_counts:
                    interest_counts[entry] += 1
                else:
                    interest_counts[entry] = 1

    # Create subplots for satisfaction and interest histograms
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    # Plot the satisfaction histogram
    ax1.bar(satisfaction_counts.keys(), satisfaction_counts.values())
    ax1.set_xlabel('Satisfaction Level')
    ax1.set_ylabel('Count')
    ax1.set_title('How Satisfied with Solution')

    # Plot the interest histogram
    ax2.bar(interest_counts.keys(), interest_counts.values())
    ax2.set_xlabel('Interest Level')
    ax2.set_ylabel('Count')
    ax2.set_title('How Interested in Implementing')

    # Adjust the spacing between subplots
    plt.tight_layout()

    # Display the plot
    plt.show()

plot_feedback_histogram(feedback_entries)

# %%
from wordcloud import WordCloud

def generate_word_cloud(text, title):
    # Generate the word cloud
    print(f'text: {text}')
    if text:
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

        # Plot the word cloud
        plt.figure(figsize=(10, 5))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.title(title)
        plt.tight_layout()
        plt.show()

def strip_unnecessary_words(input_string):
    unnecessary_words = ["Not for now", "N/A", "N\A", "no", "No", "Not for now", "None", "Nope", "Na", "NA", "N", "N/a", "n/a", "Nope", "-", "Nothing", "Need to try", "Not yet", "Nope", "not sure yet"]
    
    # Split the input string into individual entries
    entries = input_string.split(", ")
    
    # Filter out unnecessary words from each entry
    filtered_entries = [entry for entry in entries if entry not in unnecessary_words]
    
    # Join the filtered entries back into a string
    output_string = ", ".join(filtered_entries)
    
    return output_string

def visualize_other_fields(feedback_entries):
    # Extract the values of other fields using regular expressions
    ai_applications = []
    deployment_methods = []
    tools_of_interest = []
    feature_requests = []
    additional_topics = []

    for entries in feedback_entries:
        for entry in entries:
            ai_applications.extend(re.findall(r'AI Applications: (.*)', entry))
            deployment_methods.extend(re.findall(r'Deployment Method: (.*)', entry))
            tools_of_interest.extend(re.findall(r'Tools of Interest: (.*)', entry))
            feature_requests.extend(re.findall(r'Feature Requests or Changes: (.*)', entry))
            additional_topics.extend(re.findall(r'Additional Topics: (.*)', entry))

    # Join the values into strings
    ai_applications_text = ', '.join(ai_applications)
    deployment_methods_text = ', '.join(deployment_methods)
    tools_of_interest_text = ', '.join(tools_of_interest)
    feature_requests_text = ', '.join(feature_requests)
    additional_topics_text = ', '.join(additional_topics)

    # Strip some unnecessary words
    feature_requests_text = strip_unnecessary_words(feature_requests_text)
    additional_topics_text = strip_unnecessary_words(additional_topics_text)

    # Generate word clouds for each field
    generate_word_cloud(ai_applications_text, 'AI Applications')
    generate_word_cloud(deployment_methods_text, 'Deployment Methods')
    generate_word_cloud(tools_of_interest_text, 'Tools of Interest')
    generate_word_cloud(feature_requests_text, 'Feature Requests or Changes')
    generate_word_cloud(additional_topics_text, 'Additional Topics')

visualize_other_fields(feedback_entries)
# Out:
# text: , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Recommendation System, Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Recommendation System, Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Data Analytics, Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Data Analytics, Image / Video Generation, Large Language Model (LLM), Recommendation System, Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM), Large Language Model (LLM
# ...

# %%
text = "Not for now, N\A, Need to try, Na, NA, The user interface is great and I loved the demo. Would love to use more for a longer time and provide more feedback, None, Faster computing, Faster processing, Faster ai computing, NA, Not at this time, NA, Nope, Easy to use., Just to know what vector stores are available, Yes, Not yet, Na, More kernel dev, None, N, None, Ask questions about statistics of the repository, Not currently, NA, Not at the moment, Linux desktop support, Music creation, Not sure, Na, faster model training, Ai, Agentic functionality, Yes, Ai implementation, RAG with personal documents on device, Not at the moment, Nothing, None that I can think of yet, Na, Discussed with presenter, Na, Azure Devops repo support, Easier deployment, Na, Na, A preamble of suggested use cases., None, ai, Na, I don't believe I am at the technical level for that yet, Local storage, None"
print(strip_unnecessary_words(text))
# Out:
# The user interface is great and I loved the demo. Would love to use more for a longer time and provide more feedback, Faster computing, Faster processing, Faster ai computing, Not at this time, Easy to use., Just to know what vector stores are available, Yes, More kernel dev, Ask questions about statistics of the repository, Not currently, Not at the moment, Linux desktop support, Music creation, Not sure, faster model training, Ai, Agentic functionality, Yes, Ai implementation, RAG with personal documents on device, Not at the moment, None that I can think of yet, Discussed with presenter, Azure Devops repo support, Easier deployment, A preamble of suggested use cases., ai, I don't believe I am at the technical level for that yet, Local storage
